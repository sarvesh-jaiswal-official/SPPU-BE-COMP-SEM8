# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(housing.data, housing.target, test_size=0.2, random_state=42)

# %%
# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Load the Boston Housing dataset  | Note: Not using Boston Dataset since it's deprecated
# boston = load_boston()

# Load the California Housing dataset
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
housing = fetch_california_housing()

# %%
# Build the model
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# %%
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 516/516 [==============================] - 2s 2ms/step - loss: 0.7802
# Epoch 2/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.4506
# Epoch 3/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3679
# Epoch 4/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3501
# Epoch 5/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3339
# Epoch 6/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3291
# Epoch 7/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3149
# Epoch 8/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3100
# Epoch 9/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.3033
# Epoch 10/100
# 516/516 [==============================] - 1s 3ms/step - loss: 0.3151
# Epoch 11/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2934
# Epoch 12/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2926
# Epoch 13/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2918
# Epoch 14/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2871
# Epoch 15/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2826
# Epoch 16/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2796
# Epoch 17/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2786
# Epoch 18/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2764
# Epoch 19/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2737
# Epoch 20/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2732
# Epoch 21/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2786
# Epoch 22/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2713
# Epoch 23/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2670
# Epoch 24/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2644
# Epoch 25/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2632
# Epoch 26/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2613
# Epoch 27/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2605
# Epoch 28/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2623
# Epoch 29/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2591
# Epoch 30/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2577
# Epoch 31/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2591
# Epoch 32/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2541
# Epoch 33/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2555
# Epoch 34/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2524
# Epoch 35/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2516
# Epoch 36/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2499
# Epoch 37/100
# 516/516 [==============================] - 1s 3ms/step - loss: 0.2513
# Epoch 38/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2489
# Epoch 39/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2470
# Epoch 40/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2462
# Epoch 41/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2494
# Epoch 42/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2463
# Epoch 43/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2469
# Epoch 44/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2429
# Epoch 45/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2427
# Epoch 46/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2388
# Epoch 47/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2403
# Epoch 48/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2388
# Epoch 49/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2375
# Epoch 50/100
# 516/516 [==============================] - 1s 3ms/step - loss: 0.2383
# Epoch 51/100
# 516/516 [==============================] - 1s 3ms/step - loss: 0.2365
# Epoch 52/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2342
# Epoch 53/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2350
# Epoch 54/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2335
# Epoch 55/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2340
# Epoch 56/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2291
# Epoch 57/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2346
# Epoch 58/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2279
# Epoch 59/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2325
# Epoch 60/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2300
# Epoch 61/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2253
# Epoch 62/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2257
# Epoch 63/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2247
# Epoch 64/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2255
# Epoch 65/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2235
# Epoch 66/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2250
# Epoch 67/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2225
# Epoch 68/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2221
# Epoch 69/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2210
# Epoch 70/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2183
# Epoch 71/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2202
# Epoch 72/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2183
# Epoch 73/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2291
# Epoch 74/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2249
# Epoch 75/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2178
# Epoch 76/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2171
# Epoch 77/100
# 516/516 [==============================] - 1s 3ms/step - loss: 0.2147
# Epoch 78/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2145
# Epoch 79/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2161
# Epoch 80/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2138
# Epoch 81/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2142
# Epoch 82/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2122
# Epoch 83/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2137
# Epoch 84/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2117
# Epoch 85/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2124
# Epoch 86/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2129
# Epoch 87/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2119
# Epoch 88/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2115
# Epoch 89/100
# 516/516 [==============================] - 1s 3ms/step - loss: 0.2111
# Epoch 90/100
# 516/516 [==============================] - 1s 3ms/step - loss: 0.2109
# Epoch 91/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2088
# Epoch 92/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2068
# Epoch 93/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2094
# Epoch 94/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2055
# Epoch 95/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2082
# Epoch 96/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2098
# Epoch 97/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2077
# Epoch 98/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2060
# Epoch 99/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2054
# Epoch 100/100
# 516/516 [==============================] - 1s 2ms/step - loss: 0.2062

# %%
# Evaluate the model
loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Test Loss: {loss}')
# Out:
# Test Loss: 0.25143370032310486

# %%
# Predict on test data
y_pred = model.predict(X_test)
# Out:
# 129/129 [==============================] - 0s 1ms/step

# %%
# Display sample predictions
for i in range(10):
    print(f'True Price: {y_test[i]}, Predicted Price: {y_pred[i][0]}')
# Out:
# True Price: 0.477, Predicted Price: 0.458491712808609
# True Price: 0.458, Predicted Price: 0.636107325553894
# True Price: 5.00001, Predicted Price: 4.953542232513428
# True Price: 2.186, Predicted Price: 2.605693817138672
# True Price: 2.78, Predicted Price: 2.7198429107666016
# True Price: 1.587, Predicted Price: 1.6797741651535034
# True Price: 1.982, Predicted Price: 2.230220317840576
# True Price: 1.575, Predicted Price: 1.5271650552749634
# True Price: 3.4, Predicted Price: 2.346857786178589
# True Price: 4.466, Predicted Price: 4.78497838973999
